# %%
import pandas as pd
import numpy as np

# %%
crime=pd.read_csv('Chicago_Crime_Detective.csv')
crime.head(1500)
# Out:
#       Unnamed: 0       ID            Date            LocationDescription  \
# 0              0  8951354  12/31/12 23:15                         STREET
# 1              1  8951141  12/31/12 22:00                         STREET
# 2              2  8952745  12/31/12 22:00  RESIDENTIAL YARD (FRONT/BACK)
# 3              3  8952223  12/31/12 22:00                         STREET
# 4              4  8951608  12/31/12 21:30                         STREET
# ...          ...      ...             ...                            ...
# 1495        1495  8902480  11/25/12 19:00                         STREET
# 1496        1496  8901924  11/25/12 18:00                         STREET
# 1497        1497  8902504  11/25/12 17:30                         STREET
# 1498        1498  8918324  11/25/12 17:30                         STREET
# 1499        1499  8902447  11/25/12 17:00                         STREET
#
#       Arrest  Domestic  Beat District CommunityArea  Year
# ...

# %%
crime.median(axis=0)
# Out:
# Unnamed: 0      95820.0
# ID            4762956.0
# Arrest              0.0
# Domestic            0.0
# Beat             1121.0
# Year             2006.0
# dtype: float64

# %%
crime.shape
# Out:
# (191641, 10)

# %%
crime.Date.dtype
# Out:
# dtype('O')

# %%
crime_datetime_format = np.array(pd.to_datetime(crime['Date']), dtype=np.datetime64)
crime_numeric_format = pd.to_numeric(crime_datetime_format)
median_numeric_format = np.median(crime_numeric_format)
median_datetime_format = pd.to_datetime(median_numeric_format)
median_datetime_format
# Out:
# Timestamp('2006-05-21 12:30:00')

# %%
crime.Date.value_counts()
# Out:
# 5/16/08 0:00      11
# 4/13/04 21:00     10
# 9/17/05 22:00     10
# 10/17/01 22:00    10
# 10/26/01 22:00     9
#                   ..
# 7/24/05 0:01       1
# 6/3/10 22:00       1
# 3/30/10 0:15       1
# 5/27/12 18:00      1
# 9/18/05 10:50      1
# Name: Date, Length: 131680, dtype: int64

# %%
crime.Date=pd.to_datetime(crime.Date)
crime.Date
# Out:
# 0        2012-12-31 23:15:00
# 1        2012-12-31 22:00:00
# 2        2012-12-31 22:00:00
# 3        2012-12-31 22:00:00
# 4        2012-12-31 21:30:00
#                  ...
# 191636   2001-01-01 00:05:00
# 191637   2001-01-01 00:01:00
# 191638   2001-01-01 00:01:00
# 191639   2001-01-01 00:01:00
# 191640   2001-01-01 00:01:00
# Name: Date, Length: 191641, dtype: datetime64[ns]

# %%
crime['Month']=crime.Date.dt.month
crime.head(1500)
# Out:
#       Unnamed: 0       ID                Date            LocationDescription  \
# 0              0  8951354 2012-12-31 23:15:00                         STREET
# 1              1  8951141 2012-12-31 22:00:00                         STREET
# 2              2  8952745 2012-12-31 22:00:00  RESIDENTIAL YARD (FRONT/BACK)
# 3              3  8952223 2012-12-31 22:00:00                         STREET
# 4              4  8951608 2012-12-31 21:30:00                         STREET
# ...          ...      ...                 ...                            ...
# 1495        1495  8902480 2012-11-25 19:00:00                         STREET
# 1496        1496  8901924 2012-11-25 18:00:00                         STREET
# 1497        1497  8902504 2012-11-25 17:30:00                         STREET
# 1498        1498  8918324 2012-11-25 17:30:00                         STREET
# 1499        1499  8902447 2012-11-25 17:00:00                         STREET
#
# ...

# %%
crime.Month.value_counts()
# Out:
# 10    17086
# 7     16801
# 8     16572
# 12    16426
# 11    16063
# 9     16060
# 1     16047
# 5     16035
# 6     16002
# 3     15758
# 4     15280
# 2     13511
# Name: Date, dtype: int64

# %%
crime['Weekday']=crime.Date.dt.weekday_name
crime.head(1500)
# Out:
#       Unnamed: 0       ID                Date            LocationDescription  \
# 0              0  8951354 2012-12-31 23:15:00                         STREET
# 1              1  8951141 2012-12-31 22:00:00                         STREET
# 2              2  8952745 2012-12-31 22:00:00  RESIDENTIAL YARD (FRONT/BACK)
# 3              3  8952223 2012-12-31 22:00:00                         STREET
# 4              4  8951608 2012-12-31 21:30:00                         STREET
# ...          ...      ...                 ...                            ...
# 1495        1495  8902480 2012-11-25 19:00:00                         STREET
# 1496        1496  8901924 2012-11-25 18:00:00                         STREET
# 1497        1497  8902504 2012-11-25 17:30:00                         STREET
# 1498        1498  8918324 2012-11-25 17:30:00                         STREET
# 1499        1499  8902447 2012-11-25 17:00:00                         STREET
#
# ...

# %%
crime.Weekday.value_counts()
# Out:
# Friday       29284
# Wednesday    27416
# Monday       27397
# Thursday     27319
# Saturday     27118
# Tuesday      26791
# Sunday       26316
# Name: Weekday, dtype: int64

# %%
crime.groupby('Arrest')['Month'].value_counts()
# Out:
# Arrest  Month
# False   10       15744
#         7        15477
#         8        15243
#         12       15029
#         5        14848
#         9        14812
#         11       14807
#         6        14772
#         1        14612
#         3        14460
#         4        14028
#         2        12273
# True    1         1435
#         12        1397
#         10        1342
#         8         1329
#         7         1324
#         3         1298
#         11        1256
#         4         1252
#         9         1248
#         2         1238
#         6         1230
#         5         1187
# Name: Month, dtype: int64

# %%
from matplotlib import pyplot as plt
# %matplotlib inline
crime.Year.value_counts().sort_index().plot()

# %%
crime.groupby('Arrest')['Year'].value_counts().sort_index()
# Out:
# Arrest  Year
# False   2001    18517
#         2002    16638
#         2003    14859
#         2004    15169
#         2005    14956
#         2006    14796
#         2007    13068
#         2008    13425
#         2009    11327
#         2010    14796
#         2011    15012
#         2012    13542
# True    2001     2152
#         2002     2115
#         2003     1798
#         2004     1693
#         2005     1528
#         2006     1302
#         2007     1212
#         2008     1020
#         2009      840
#         2010      701
#         2011      625
#         2012      550
# Name: Year, dtype: int64

# %%
crime.LocationDescription.value_counts().head(6)
# Out:
# STREET                            156564
# PARKING LOT/GARAGE(NON.RESID.)     14852
# OTHER                               4573
# ALLEY                               2308
# GAS STATION                         2111
# DRIVEWAY - RESIDENTIAL              1675
# Name: LocationDescription, dtype: int64

# %%
crime_filter=crime.LocationDescription.isin(['STREET','PARKING LOT/GARAGE(NON.RESID.)','ALLEY','GAS STATION','DRIVEWAY - RESIDENTIAL'])
# Out:
# 0          True
# 1          True
# 2         False
# 3          True
# 4          True
#           ...
# 191636     True
# 191637     True
# 191638     True
# 191639     True
# 191640     True
# Name: LocationDescription, Length: 191641, dtype: bool

# %%
Top5=crime[crime_filter]
Top5
# Out:
#         Unnamed: 0       ID                Date LocationDescription  Arrest  \
# 0                0  8951354 2012-12-31 23:15:00              STREET   False
# 1                1  8951141 2012-12-31 22:00:00              STREET   False
# 3                3  8952223 2012-12-31 22:00:00              STREET   False
# 4                4  8951608 2012-12-31 21:30:00              STREET   False
# 5                5  8950793 2012-12-31 20:30:00              STREET    True
# ...            ...      ...                 ...                 ...     ...
# 191636      191636  1310068 2001-01-01 00:05:00              STREET   False
# 191637      191637  1313404 2001-01-01 00:01:00              STREET   False
# 191638      191638  1313442 2001-01-01 00:01:00              STREET   False
# 191639      191639  1563324 2001-01-01 00:01:00              STREET   False
# 191640      191640  1310463 2001-01-01 00:01:00              STREET   False
#
# ...

# %%
Top5.shape
# Out:
# (177510, 12)

# %%
Top5.groupby('LocationDescription')['Weekday'].value_counts().sort_index()
# Out:
# LocationDescription             Weekday
# ALLEY                           Friday         385
#                                 Monday         320
#                                 Saturday       341
#                                 Sunday         307
#                                 Thursday       315
#                                 Tuesday        323
#                                 Wednesday      317
# DRIVEWAY - RESIDENTIAL          Friday         257
#                                 Monday         255
#                                 Saturday       202
#                                 Sunday         221
#                                 Thursday       263
#                                 Tuesday        243
#                                 Wednesday      234
# GAS STATION                     Friday         332
#                                 Monday         280
#                                 Saturday       338
#                                 Sunday         336
# ...
